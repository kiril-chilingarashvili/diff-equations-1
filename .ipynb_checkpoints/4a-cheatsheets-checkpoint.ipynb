# %% [markdown]
# # Unit 4: Exponential Response and Resonance - Part a: Operators and Exponential Response

# %% [markdown]
# ## 2. Operator Notation
#
# ### If $y_1$ and $y_2$ are two solutions to a homogeneous, linear differential equation
# ## $$ \ddot{y} + p \dot{y} + q y = 0 $$
#
# ### why is $c_1 y_1 + c_2 y_2$ a solution?
#
# ### You know superposition for linear homogeneous differential equations. We want an elegant proof because it will help us with more complicated problems, including solving higher order inhomogeneous equations.

# %% [markdown]
# ### ***The operator*** $D$
#
# ### - A function takes an input number and returns another number.
# ### - An ***operator*** takes an input ***function*** and returns another ***function***.
#
# ### For example, the ***differential operator*** $\displaystyle \frac{d}{dt}$ takes an input function $y(t)$ and returns $\displaystyle \frac{dy}{dt}$. This operator is also called $D$. For instance $De^{4t} = 4 e^{4t}$. The operator $D$ is ***linear***, which means that
# ## $$ D(f+g) = Df + Dg, \quad D(af) = aDf $$
#
# ### for any functions $f$ and $g$, and any number $a$. Because of this, $D$ behaves well with respect to linear combinations, namely
# ## $$ D(c_1 f_1 + \cdots + c_n f_n) = c_1 D f_1 + \cdots + c_n D f_n $$
#
# ### for any numbers $c_1, \ldots, c_n$ and functions $f_1,\ldots,f_n$.
#
# ### ***Example 2.1*** $Dt^3 = 3t^2$.
#
# ### ***Warning***: You can't take this equation and substitute $t=2$ to get $D8 = 12$. The only way to interpret “$8$" in “$D8$" is as a ***constant*** function, which of course has derivative zero: $D8 = 0$. The point is that in order to know the function $Df(t)$ at a particular value of $t$, say $t=a$, you need to know more than just $f(a)$; you need to know how $f(t)$ is changing near $a$ as well. This is characteristic of operators; in general you have to expect to need to know the ***whole*** function $f(t)$ in order to evaluate an operator on it.
#
# ### ***Definition 2.2***
# ### In general, a ***linear operator*** $L$ is any operator that satisfies
# ## $$ L(f+g) = Lf + Lg,\quad L(af) = aLf $$
#
# ### for any functions $f$ and $g$, and any number $a$.
#
# ### ***Example 2.3***
# ### The operator $L=D^2+p(t)D + q(t)$ where $p(t)$ and $q(t)$ are any functions of $t$ is a linear operator.
#
# ### Why is $L$ linear? You know that $D$ is linear, and similarly, $D^2$ is linear. To see that $L$ is linear, verify that a linear combination of linear operators is again a linear operator.

# %% [markdown]
# ## 3. Multiplying and adding operators
#
# ### To apply a product of two operators, apply each operator in succession. For instance, $DDy$ means take the derivative of $y$, and then take the derivative of the result; therefore we write $D^2y = \ddot{y}$.
#
# ### To apply a sum of two operators, apply each operator to the function and add the results. For instance, $(D^2+D)y = D^2y+Dy = \ddot{y}+\dot{y}$.
#
# ### Any number can be viewed as the “multiply-by-the-number" operator: for instance, the operator $5$ transforms the function $\sin(t)$ into the function $5\sin(t)$. In particular, the “identity" operator is the multiply by the number $1$ operator: $1f = f$ for all functions $f$.
#
# ### Similarly, we can multiply by any function of $t$, and this is also a linear operator. For instance, the operator $t^2$ transforms the function $\sin(t)$ into the function $t^2\sin(t)$.
#
# ### ***Example 3.1***
# ### The ODE
# ## $$ 2\ddot{y} + 3\dot{y} + 5y = 0 $$
#
# ### whose characteristic polynomial is $P(r) = 2r^2+3r+5$, can be rewritten as
# ## $$ \begin{array} {rcl} (2D^2+3D+5)y & = & 0 \\ P(D) y & = & 0 \end{array} $$
#
# ### The same argument shows that every constant-coefficient homogeneous linear ODE
# ## $$ a_n y^{(n)} + \cdots + a_0 y = 0 $$
#
# ### can be written simply as
# ## $$ P(D) y = 0 $$
#
# ### where $P$ is the characteristic polynomial.

# %% [markdown]
# ## 4. Time invariance
#
# ### In this course we'll focus on polynomial differential operators with constant coefficients, that is operators of the form
# ## $$ P(D) = a_n D^n + a_{n-1} D^{n-1}+\cdots+a_1 D + a_0 $$
#
# ### where all of the coefficients $a_k$ are numbers (as opposed to functions of $t$). All operators of this form are linear. In addition to being linear operators, they are also ***time-invariant*** operators, which means:
#
# ### If $x(t)$ solves $P(D) x = f(t)$, then $y(t) = x(t-t_0)$ solves $P(D) y = f(t-t_0)$.
#
# ### In words, this says that “delaying the input signal $f(t)$ by $t_0$ seconds delays the output signal $x(t)$ by $t_0$ seconds." If we know that $x(t)$ is a solution to $P(D)x = f(t)$, we can solve $P(D)y = f(t-t_0)$ by replacing $t$ by $t-t_0$ in $x(t)$. This is a useful property because it gives us the solutions to many differential equations for free.
#
# ### A system that can be modeled using a linear time invariant operator is called an ***LTI (linear time invariant)*** system.
#
# ### ***Example 4.1***
# ### The function $x(t) = \sin(t)$ solves the differential equation $\dot{x} = \cos(t)$.
#
# ### What is a solution to the differential equation
# ## $$ \dot{y} = \cos\left(t+\frac{\pi}{2}\right) $$
#
# ### By time-invariance, one solution is $\displaystyle y = \sin\left(t+\frac{\pi}{2}\right)$.
#
# ### Note that
# ## $$ \begin{array} {rcl} \dot{y} & = & \displaystyle \cos\left(t+\frac{\pi}{2}\right) \\ \, & = & \displaystyle \cos(t)\cos\left(\frac{\pi}{2}\right) - \sin(t)\sin\left(\frac{\pi}{2}\right) \\ \, & = & -\sin(t) \end{array} $$
#
# ### And
# ## $$ \begin{array} {rcl} y & = & \displaystyle \sin\left(t+\frac{\pi}{2}\right) \\ \, & = & \displaystyle \sin(t)\cos\left(\frac{\pi}{2}\right) + \cos(t) \sin\left(\frac{\pi}{2}\right) \\ \, & = & \cos(t) \end{array} $$
#
# ### ***Example 4.2***
# ### Consider the differential equation
# ## $$ \dot{x} + x = \cos(t) $$
#
# ### Variation of parameters or integrating factors tells us that the general solution to this differential equation is
# ## $$ x(t) = \frac{1}{2}\cos(t) + \frac{1}{2}\sin(t) + c_1 e^{-t} $$
#
# ### Now suppose that we want to solve the equation $\dot{y} + y = \sin(t)$. Since $\displaystyle \sin(t) = \cos(t-\frac{\pi}{2})$, time invariance tells us that
# ## $$ \begin{array} {rcl} y(t) & = & \displaystyle x \left( t -\frac{\pi}{2} \right) = \frac{1}{2} \cos\left( t - \frac{\pi}{2} \right) + \frac{1}{2} \sin\left( t - \frac{\pi}{2} \right) + c_1 e^{-(t-\frac{\pi}{2})} \\ \, & = & \displaystyle \frac{1}{2} \sin(t) - \frac{1}{2} \cos(t) + \underbrace{c_1 e^{\frac{\pi}{2}}}_{\text{call this}\, c_2}e^{-t} \\ \, & = & \displaystyle \frac{1}{2} \sin(t) - \frac{1}{2}\cos(t) + c_2 e^{-t} \end{array} $$
#
# ### should solve $\dot{y} + y = \sin(t)$. This agrees with the solution we'd get if we had used variation of parameters or integrating factors, but we had to do almost no work to get this solution from the first.
# ![img](img/sc13.png)

# %% [markdown]
# ## 5. Superposition for an inhomogeneous linear ODE
#
# ### This was only done for first order previously here.
#
# ### To understand the general solution  to an inhomogeneous linear ODE
# ## $$ \text{inhomogeneous equation:}\quad p_n(t) y^{(n)} + \cdots + p_0(t) y = q(t) $$
#
# ### do the following:
#
# ### 1. List all solutions to the associated homogeneous equation
# ## $$ \text{homogeneous equation:}\quad p_n(t) y^{(n)} + \cdots + p_0(t) y = 0 $$
#
# ###    i.e., write down the general homogeneous solution $y_h$.
#
# ### 2. Find (in some way) any ***one*** particular solution $y_p$ to the ***inhomogeneous*** ODE.
# ### 3. Add $y_p$ to all the solutions of the homogeneous ODE to get all the solutions to the inhomogeneous ODE.
#
# ### ***Summary***:
# ## $$ \underbrace{y}_{\text{general solution}} = \underbrace{y_p}_{\text{particular solution}} + \underbrace{y_h}_{\text{general homogeneous solution}} $$
#
# ### Why does this work?
#
# ### Let $L$ be the linear operator $L = p_n(t) D^n + \cdots + p_1(t) D + p_0 (t)$. Then the differential equations become
# ## $$ \begin{array} {rcl} \text{inhomogeneous equation} \quad L_y & = & q(t) \\ \text{homogeneous equation} \quad Ly & = & 0 \end{array} $$
#
# ### Let $y_p$ be a particular solution to the inhomogeneous equation $L(y_p) = q$. Let $y_h$ be a homogeneous solution $L(y_h)$. Then
# ## $$ L(y_p + y_h) = q + 0 = q $$
#
# ### Suppose that $y$ is also a solution to $Ly = q$. That is
# ## $$ \begin{array} {rcl} Ly & = & q \\ L y_p & = & q \end{array} $$
#
# ### Then it follows by linearity that
# ## $$ L(y-y_p) = L(y) - L(y_p) = q - q = 0 $$
#
# ### Therefore $y-y_p = y_h$ is a solution to the associated homogeneous equation. In other words,
# ## $$ y = y_p + y_h $$
#
# ### ***The result of this section is the key point of linearity in the inhomogeneous case***. It lets us build ***all*** the solutions to an inhomogeneous DE out of ***one particular solution*** provided that you have already solved the associated homogeneous ODE.

# %% [markdown]
# ## 7. Shortcut
#
# ### ***Warm-up problem***: If $r$ is a number, what is $(2D^2+3D+5)e^{rt}$?
#
# ### ***Solution***:
# ### First, $De^{rt} = re^{rt}$ and $D^2e^{rt}$ (keep applying the chain rule). Thus
# ## $$ \begin{array} {rcl} (2D^2+3D+5)e^{rt} & = & 2r^2e^{rt} + 3re^{rt} + 5e^{rt} \\ \, & = & (2r^2 + 3r + 5)e^{rt} \end{array} $$
#
# ### The operator is $P(D) = 2D^2 + 3D + 5$. Notice that $P(r) = 2r^2 + 3r + 5$ is the characteristic polynomial. The same calculation, but with an arbitrary polynomial, proves the following general rule.
#
# ### ***Theorem 7.1***
# ### For any polynomial $P$ and any number $r$,
# ## $$ P(D) e^{rt} = P(r) e^{rt} $$

# %% [markdown]
# ## 8. Exponential response formula
#
# ### ***Question***:
# ### For any polynomial $P$ and number $r$, what is a particular solution to
# ## $$ P(D) y = e^{rt} $$
#
# ### ***Answer (superposition)***:
# ### We have
# ## $$ P(D) e^{rt} = P(r) e^{rt} $$
#
# ### This is off by a factor of $P(r)$. So multiply through by $\displaystyle \frac{1}{P(r)}$ and we can use linearity to get
# ## $$ P(D) \left( \frac{1}{P(r)} e^{rt} \right) = e^{rt} $$
#
# ### ***Conclusion***:
# ### This is called the ***Exponential Response Formula (ERF)***.
#
# ### In words, for any polynomial $P$ and any number $r$ such that $P(r) \neq 0$,
# ## $$ \frac{1}{P(r)} e^{rt}\quad \text{is a particular solution to}\quad P(D)y = e^{rt} $$
#
# ### Remember, this is just one particular solution. To get the general solution, we need to add the solution to the associated homogeneous equation.
#
# ### ***Example 8.1***
# ### Find the general solution to $\ddot{y}+7 \dot{y} + 12 y = -5 e^{2t}$.
#
# ### ***Solution***:
#
# ### Characteristic polynomial: $P(r) = r^2 + 7r + 12 = (r+3)(r+4)$.
# ### Roots: $-3, -4$.
# ### General solution to ***homogeneous*** equation: $y_h = c_1 e^{-3t} + c_2 e^{-4t}$.
# ### ERF says:
# ## $$ \frac{1}{P(2)} e^{2t}\quad \text{is a particular solution to}\quad P(D) y = e^{2t}  $$
#
# ### i.e.,
# ## $$ \frac{1}{30}e^{2t} \quad \text{is a particular solution to}\quad \ddot{y} + 7\dot{y} + 12 y = e^{2t} $$
#
# ### so
# ## $$ \underbrace{\displaystyle -\frac{1}{6}e^{2t}}_{\text{call this}\, y_p} \quad \text{is a particular solution to} \quad \ddot{y} + 7 \dot{y} + 12 y = -5 e^{2t} $$
#
# ### General solution to inhomogeneous equation:
# ## $$ \begin{array} {rcl} y & = & y_p + y_h \\ \, & = & \displaystyle -\frac{1}{6} e^{2t} + c_1 e^{-3t} + c_2 e^{-4t} \end{array} $$

# %% [markdown]
# ## 9. ERF and complex roots
#
# ### The ERF works equally well for complex exponential inputs.
#
# ### ***Example 9.1***
# ### Use ERF to find a particular solution to
# ## $$ \ddot{x} + x = e^{2it} $$
#
# ### ***Solution***:
# ### In operator notation, this differential equation can be written as
# ## $$ (D^2 + 1)x = e^{2it} $$
#
# ### By the ERF, a particular solution is given by
# ## $$ x_p = \frac{e^{rt}}{r^2+1} = \frac{e^{2it}}{(2i)^2 + 1} = -\frac{1}{3}e^{2it} $$

# %% [markdown]
# ## 10. The generalized exponential response formula
#
# ### The existence and uniqueness theorem says that
# ## $$ P(D) y = e^{rt} $$
#
# ### should have a solution even if $P(r) = 0$ (when ERF does not apply). Let's start with the one case:
#
# ### ***ERF'*** Suppose that $P$ is a polynomial and $P(r_0) = 0$, but $P'(r_0) \neq 0$ for some number $r_0$. Then
# ## $$ \boxed{ x_p = \frac{1}{P'(r_0)} t e^{r_0 t} \quad \text{is a particular solution to}\quad P(D) x = e^{r_0 t} } $$

# %% [markdown]
# ### ***Proof***
#
# ### We want to solve $P(D) y = e^{r_0 t}$. We know that
# ## $$ P(D) e^{rt} = P(r) e^{rt} $$
#
# ### for all $r$, so in particular $P(D) e^{r_0 t} = P(r_0) e^{r_0 t}$. However, since $P(r_0)$ is zero, we cannot divide by it.
#
# ### Instead, let us look at what happens for $r$ near $r_0$ by differentiating with respect to $r$, and then substituting $r=r_0$:
# ## $$ \frac{\partial}{\partial r} (P(D)e^{rt}) = \frac{\partial}{\partial r} (P(r) e^{rt}) = P'(r)e^{rt} + P(r) te^{rt} $$
#
# ### We need to take the derivative of the left hand side. Recall from [18.02 Multivariable Calculus](https://kiril-chilingarashvili.github.io/multivar-calculus-1/3-cheatsheets.html#:~:text=fxy-,Important%20Fact,-%3A%20If%20a%20function) that
# ## $$ \frac{\partial}{\partial r} \frac{\partial}{\partial t} =\frac{\partial}{\partial t} \frac{\partial}{\partial r}  $$
#
# ### In this context, this means the same thing as
# ## $$ \frac{\partial}{\partial r} D = D \frac{\partial}{\partial r} \quad \left( D = \frac{d}{dt} \right) $$
#
# ### Hence
# ## $$ \frac{\partial}{\partial r} P(D) = P(D) \frac{\partial}{\partial r} $$
#
# ### by linearity.
#
# ### The left hand side becomes.
# ## $$ \begin{array} {rcl} \displaystyle \frac{\partial}{\partial r} (P(D) e^{rt}) & = & \displaystyle P(D) \left( \frac{\partial}{\partial r} e^{rt} \right) \\ \, & = & P(D) (t e^{rt}) \end{array} $$
#
# ### Let $r \to r_0$. Therefore since $P(r_0) = 0$
# ## $$ \begin{array} {rcl} P(D) (t e^{r_0 t}) & = & P'(r_0) e^{r_0 t} + P(r_0) t e^{r_0 t} \\ \, & = & P'(r_0) e^{r_0 t} \end{array} $$
#
# ### If $P'(r_0) \neq 0$, then we can divide through by $P'(r_0)$
# ## $$ P(D) \left( \frac{t e^{r_0 t}}{P'(r_0)} \right) = e^{r_0 t} $$
#
# ### and $\displaystyle y_p = \frac{t e^{r_0 t}}{P'(r_0)}$ is a particular solution to $P(D) y = e^{r_0 t}$.

# %% [markdown]
# ### ***Example 10.1***
# ### Find a particular solution to $\ddot{x} -4x = e^{-2t}$.
#
# ### ***Solution***:
# ### The characteristic polynomial is $P(r) = r^2 - 4$, thus $P(-2) = 0$. But $P'(-2) = 2(-2) = -4 \neq 0$. Therefore this is a case where we can apply ERF, which gives us a particular solution
# ## $$ x_p = \frac{t e^{rt}}{P'(r)} = \frac{t e^{-2t}}{-4} $$
#
# ### ***Generalized exponential response formula***.
# ### If $P$ is a polynomial and $r_0$ is a number such that
# ## $$ P(r_0) = P'(r_0) = \cdots = P^{(m-1)}(r_0) = 0\quad P^{(m)}(r_0) \neq 0 $$
#
# ### then
# ## $$ P(D) (t^m e^{r_0 t}) = P^{(m)} (r_0) e^{r_0 t} $$
#
# ### and
# ## $$ \boxed{ y_p = \frac{1}{P^{(m)}(r_0)} t^m e^{r_0 t} \quad \text{is a particular solution to}\quad P(D)y = e^{r_0 t} } $$
#
# ### In other words, multiply the input signal by $t^m$, and then multiply by the number $\displaystyle \frac{1}{P^{(m)}(r_0)}$, where $P^{(m)}$ is the $m^{\text{th}}$ derivative of $P$.
# ### The proof of the Generalized ERF is similar to the proof of ERF'.

# %% [markdown]
# ### ***Proof of Generalized ERF***
# ### We want to solve $P(D) y = e^{rt}$. We know that
# ## $$ P(D) e^{r_0 t} = P(r_0) e^{r_0 t} $$
#
# ### for all $r$. However, since $P(r_0)$ is zero, we cannot divide by it.
#
# ### Instead, let us look at what happens near this point $r_0$ and differentiate with respect to $r$.
# ## $$ \begin{array} {rcl} \displaystyle P(D) e^{rt} & = & \displaystyle P(r) e^{rt} \\ \displaystyle \frac{\partial}{\partial r}(P(D)e^{rt}) & = & \displaystyle \frac{\partial}{\partial r}(P(r) e^{rt}) \\ \displaystyle P(D) \left( \frac{\partial}{\partial r} e^{rt} \right) & = & \displaystyle P'(r) e^{rt} + P(r) t e^{rt} \end{array} $$
#
# ### In the case that $r_0$ is a repeated root with multiplicity $m$, then $P(r) = Q(r) (r-r_0)^m$, and
# ## $$ \frac{\partial^m}{\partial r^m} P(r_0) \neq 0 $$
#
# ### however, all lower derivatives are zero at $r$
# ## $$ \begin{array} {rcl} \displaystyle \frac{\partial^{m-1}}{\partial r^{m-1}} P(r_0) & = & 0 \\ \vdots & & \vdots \\ P(r_0) & = & 0 \end{array} $$
#
# ### Differentiate both sides of the equation $m$ times with respect to $r$ to obtain a relationship:
# ## $$ P(D) (t^m e^{rt}) = \left( P^{(m)}(r) + m t P^{(m-1)}(r) + \frac{m(m-1)}{2} t^2 P^{(m-2)}(r) + \cdots + t^m P(r) \right) e^{rt} $$
#
# ### Evaluating at $r_0$, only the $m^{\text{th}}$ derivative term survives
# ## $$ P(D) (t^m e^{r_0 t}) = P^{(m)} (r_0) e^{r_0 t} $$
#
# ### which gives a particular solution to the differential equation $P(D)y = e^{r_0 t}$ of the form $\displaystyle y_p = \frac{t^m e^{r_0 t}}{P^{(m)}(r_0)}$.

# %% [markdown]
# ### ***Example 10.2***
# ### Solve the system $\ddot{x} + x = e^{it}$ with initial conditions $x(0) = 1$ and $\dot{x}(0) = 0$.
#
# ### ***Worked solution***
# ### The characteristic polynomial of the differential equation $\ddot{x} + x = e^{it}$ is $P(r) = r^2 + 1$, with roots $\pm i$. Since $i$ is a root of the characteristic polynomial, the ***Generalized ERF*** tells us to find the smallest integer $s$ for which $P^{(s)}(i)\neq 0$. In this case, $P'(r) = 2r$, so $P'(i) = 2i$, which is not zero, so $s=1$. The Generalized ERF tells us that
# ## $$ x_p(t) = \frac{1}{P'(i)} t^1 e^{it} = \frac{1}{2i} t e^{it} $$
#
# ### is a particular solution to the inhomogeneous ODE. Since $\displaystyle \frac{1}{i} = e^{-\frac{i\pi}{2}}$, we can write $x_p$ as
# ## $$ x_p(t) = \frac{1}{2} t e^{it - \frac{i\pi}{2}} $$
#
# ### Since the characteristic polynomial has roots $\pm i$, we know that the pair
# ## $$ e^{it}, e^{-it} $$
#
# ### form a basis for the space of solutions to the homogeneous equation $\ddot{x} + x = 0$. Hence, the general solution to the inhomogeneous equation $\ddot{x} + x = e^{it}$ is
# ## $$ x(t) = \underbrace{c_1 e^{it} + c_2 e^{-it}}_{\text{general solution to homogeneous ODE}} + \underbrace{\frac{1}{2}t e^{it - \frac{i\pi}{2}}}_{\text{particular solution}} $$
#
# ### Now we just need to solve for the constants $c_1$ and $c_2$ from the initial conditions $x(0) = 1$ and $\dot{x}(0) = 0$. We see that
# ## $$ x(0) = 1 = c_1 + c_2 $$
#
# ### so $c_2 = 1 - c_1$, and we can write $x(t)$ as
# ## $$ x(t) = c_1 e^{it} + (1-c_1)e^{-it} + \frac{1}{2}te^{it - \frac{i\pi}{2}} $$
#
# ### We see that
# ## $$ \dot{x}(t) = i c_1 e^{it} - i(1-c_1) e^{-it} + \frac{1}{2} e^{it-\frac{i\pi}{2}} + \frac{1}{2} t e^{it} $$
#
# ### so
# ## $$ \begin{array} {rcl} \dot{x}(0) & = & \displaystyle i c_1 - i(1-c_1) + \frac{1}{2} e^{-\frac{i\pi}{2}} \\ \, & = & \displaystyle ic_1 - i(1-c_1) - \frac{i}{2} \end{array} $$
#
# ### Using initial condition $\dot{x}(0) = 0$ and solving for $c_1$ we see that $\displaystyle c_1 = \frac{3}{4}$. Substituting this into the equation $c_2 = 1-c_1$, we see that $\displaystyle c_2 = \frac{1}{4}$. Thus the solution to the system $\ddot{x}+x = e^{it}$ with initial conditions $x(0) = 1$ and $\dot{x}(0) = 0$ is
# ## $$ x(t) = \frac{3}{4}e^{it} + \frac{1}{4}e^{-it}+\frac{1}{2}t e^{it - \frac{i\pi}{2}} $$

# %% [markdown]
# ## 12. Review: Basis of homogeneous solutions with linear operators
#
# ### Recall the method for [finding a basis of solutions](https://kiril-chilingarashvili.github.io/diff-equations-1/2c-cheatsheets.html#:~:text=6.%20Characteristic%20polynomial) to a constant-coefficient homogeneous linear ODE, now written as $P(D) y = 0$. Using operators, we can explain why it works.
#
# ### ***Example 12.1***
# ### Consider the ODE
# ## $$ y'''-10y''+31y'-30y = 0 $$
#
# ### Rewriting this using operator notation we have $P(D)y=0$ where $P(r) = r^3 -10r^2+31r-30$ is the characteristic polynomial of the ODE. The trick now is to factor the operator, and proceed from there. The characteristic polynomial factors as $P(r) = (r-2)(r-3)(r-5)$. The order is $3$, so the dimension of the vector space of solutions is $3$.
#
# ### Now
#
# ### $e^{2t}$ is a solution since $P(D) e^{2t} = P(2) e^{2t} = 0 e^{2t} = 0$,
# ### $e^{3t}$ is a solution since $P(D) e^{3t} = P(3) e^{3t} = 0 e^{3t} = 0$, and
# ### $e^{5t}$ is a solution since $P(D) e^{5t} = P(5) e^{5t} = 0 e^{5t} = 0$.
# ### Just because we wrote down $3$ solutions does not mean that they form a basis: If we had written down $e^{2t}, e^{3t}, 4e^{2t} + 6e^{3t}$, then they would ***not*** have been a basis, because they are linearly dependent (and their span is only $2$-dimensional).
#
# ### To know that $e^{2t}, e^{3t}, e^{5t}$ really form a basis, we need to know that they are ***linearly independent***. Could it instead be that
# ## $$ e^{5t} = c_1 e^{2t} + c_2 e^{3t} \quad(\text{as functions}) $$
#
# ### for some numbers $c_1, c_2$?
#
# ### One way to see that this is not possible is to apply $(D-2)(D-3)$ to both sides, which would give
# ## $$ \begin{array} {rcl} (D-2)(D-3) e^{5t} & = & (D-2)(D-3)(c_1 e^{2t} + c_2 e^{3t}) \\ \, & = & c_1(D-2)(D-3)e^{2t}+c_2(D-2)(D-3)e^{3t} \quad (\text{by linearity}) \\ \, & = & c_1 \cdot 0 + c_2 \cdot 0 = 0 \end{array} $$
#
# ### The left hand side gives us
# ## $$ (D-2)(D-3) e^{5t} = (5-2)(5-3)e^{5t} \neq 0 $$
#
# ### This contradiction implies that $e^{5t}$ is not a linear combination of $e^{2t}$ and $e^{3t}$. The same argument shows that no one of $e^{2t}, e^{3t}, e^{5t}$ is a linear combination of the other two. Since $e^{2t}, e^{3t}, e^{5t}$ are linearly independent, they form a basis for a $3$-dimensional space (which must be the space of all solutions, since that too is $3$-dimensional).

# %% [markdown]
# ## 13. Review: repeated roots with linear operators
#
# ### What about the case of repeated roots?
#
# ### This case is less important than the others, because if someone hands you a polynomial it's unlikely that two or more of its roots will coincide. But it does happen, and it is interesting to think about what happens.
#
# ### ***Example 13.1***
# ### Find a basis of solutions to
# ## $$ D^3 y = 0 $$
#
# ### (The characteristic polynomial is $r^3$, whose roots with multiplicity are $0, 0, 0$.)
#
# ### ***Solution***:
# ### Integrate three times:
# ## $$ \begin{array} {rcl} D^2 y & = & c_1 \\ D y & = & c_1 t + c_2 \\ y & = & \displaystyle c_1 \frac{t^2}{2} + c_2 t + c_3 \\ \, & = & \underbrace{C_1 t^2 + c_2 t + c_3}_{\text{general solution}} \end{array} $$
#
# ### for some numbers $\displaystyle C_1 = \frac{c_1}{2}, c_2$ and $c_3$. Since $t^2, t, 1$ are linearly independent, they form a basis for the space of solutions.
#
# ### ***Example 13.2***
# ### Find a basis of solutions to
# ## $$ (D-5)^3 y = 0 $$
#
# ### ***Solution***:
#
# ### The characteristic polynomial is $(r-5)^3$, which has a repeated root $5, 5, 5$, so based on the previous example, we might hope that $e^{5t}, t e^{5t}, t^2 e^{5t}$ are a basis. Let's now explain ***why*** these are solutions.
#
# ### We know that $D-5$ sends $e^{5t}$ to $0$. What does $D-5$ do to $u e^{5t}$, if $u$ is a function of $t$? Using the product rule:
# ## $$ \begin{array} {rcl} (D-5) u e^{5t} & = & (\dot{u} e^{5t} + u 5 e^{5t}) - 5u  e^{5t} \\ \, & = & \dot{u} e^{5t} \end{array} $$
#
# ### Replacing $(D-5)$ by $(D-5)^2$ and $(D-5)^3$ on the left we get the following:
# ## $$ \begin{array} {rcl} (D-5)^2 u e^{5t} & = & \ddot{u} e^{5t} \\ (D-5)^3 u e^{5t} & = & u^{(3)} e^{5t} \end{array} $$
#
# ### So our guess was right! In order for $u e^{5t}$ to be a solution to $(D-5)^3 y = 0$ the function $u^{(3)}$ must be $0$; i.e., $u = a + bt + ct^2$ for some numbers $a,b,c$, so the solutions are
# ## $$ u e^{5t} = a e^{5t} + b t e^{5t} + c t^2 e^{5t} $$
#
# ### as expected.
#
# ### Since $1,t,t^2$ are linearly independent functions, so are $e^{5t}, t e^{5t}, t^2 e^{5t}$ (any relation between the last three functions could be divided by $e^{5t}$ to get a relation between the first three). Thus $e^{5t}, t e^{5t}, t^2 e^{5t}$ form a basis.
#
# ### If a characteristic polynomial $P(r)$ has a root $r$ which is repeated $k$ times, then $e^{rt}, t e^{rt}, t^2 e^{rt}, \ldots,t^{k-1} e^{rt}$ are independent solutions to the differential equation $P(D) y = 0$.

# %% [markdown]
# ## 14. Worked Examples
#
# ### ***Example 14.1***
# ### Find the general solution to the differential equation
# ## $$ 2\ddot{x} + \dot{x} + x = 1 + 2e^t $$
#
# ### ***Worked Solution***
# ### This is an inhomogeneous linear equation, so the general solution has the form $x_p + x_h$, where $x_p$ is any particular solution and $x_h$ is the general homogeneous solution. The characteristic polynomial is $P(s) = 2s^2 + s + 1$, with roots $\displaystyle \frac{-1\pm \sqrt{7}i}{4}$, and the general homogeneous solution is given by
# ## $$ \begin{array} {rcl} x_h(t) & = & \displaystyle e^{-\frac{t}{4}}\left( c_1 \cos \left( \frac{t\sqrt{7}}{4} \right) + c_2 \sin \left( \frac{t\sqrt{7}}{4} \right) \right) \\ \, & = & \displaystyle A e^{-\frac{t}{4}} \cos \left( \frac{t\sqrt{7}}{4} - \phi \right) \end{array} $$
#
# ### The inhomogeneous equation is $P(D) x = 1 + 2 e^{t}$.
# ### The input signal is a linear combination of $1$ and $e^t$, so we can find particular solutions to $P(D) x = 1$ and $P(D) x = e^t$ separately, then use superposition to construct a particular solution to $P(D) x = 1 + 2 e^t$.
# ### If $x_1$ is a particular solution to $P(D) x = 1$, and $x_2$ is a particular solution to $P(D) x = e^t$, then superposition says that a particular solution to $P(D) x = 1 + 2 e^t$ is given by
# ## $$ x_p = x_1 + 2 x_2 $$
#
# ### The constant function $1$ is an exponential: $e^{0t}$. Thus $P(D) x = 1$ has a particular solution
# ## $$ x_1 = \frac{1}{P(0)} = 1 $$
#
# ### (More elementarily, we've learned to look for constant solutions when the right hand side is constant, and solving $P(D) c = 1$ gives $c=1$.)
#
# ### Similarly, the ERF tells us that
# ## $$ x_2 = \frac{1}{P(1)}e^t = \frac{1}{4} e^t $$
#
# ### is a particular solution to $P(D) x = e^t$. Thus
# ## $$ \begin{array} {rcl} x_p & = & 1 + 2 \left( \frac{1}{4} e^t \right) \\ \, & = & 1 + \frac{1}{2}e^t \end{array} $$
#
# ### is a particular solution to $P(D) x = 1 + 2 e^t$. So the general solution to $2\ddot{x} + \dot{x} + x = 1 + 2 e^t$ is
# ## $$ x(t) = 1 + \frac{1}{2}e^t + A e^{-\frac{t}{4}} \cos \left( \frac{t\sqrt{7}}{4} - \phi \right) $$
#
# ### ***Example 14.2***
# ### Find a particular solution to the equation
# ## $$ \ddot{x} + 8 \dot{x} + 15 x = e^{-5t} $$
#
# ### ***Worked Solution***
# ### The characteristic polynomial is $P(r) = r^2 + 8r + 15$. Since $P(-5) = 0$ we need to use the generalized ERF.
#
# ### Computing we see that $P'(r) = 2r + 8$, and $P'(-5) = -2$. Therefore the generalized ERF gives a particular solution of
# ## $$ x_p = \frac{t e^{-5t}}{P'(-5)} = -\frac{t e^{-5t}}{2} $$
#
# ### (Of course, there are other particular solutions.)
